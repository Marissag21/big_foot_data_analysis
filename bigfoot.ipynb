# %%
# Dependencie
import pandas as pd
import numpy as np
from datetime import datetime as dt

# %%
# Load in file
bigfoot_csv_path = "Resources/bfro_reports_geocoded.csv"

# %%
# Read and display the CSV with Pandas
bigfoot_file_df = pd.read_csv(bigfoot_csv_path, header=0)
bigfoot_file_df
# Out:
#                                                observed  \
# 0     I was canoeing on the Sipsey river in Alabama....
# 1     Ed L. was salmon fishing with a companion in P...
# 2     While attending U.R.I in the Fall of 1974,I wo...
# 3     Hello, My name is Doug and though I am very re...
# 4     It was May 1984. Two friends and I were up in ...
# ...                                                 ...
# 5016  while camping protecting other equipment befor...
# 5017  I was on my way to work on a Saturday morning ...
# 5018  On the twenty sixth and again on the twenty se...
# 5019  I was hunting on me and my neighbor's property...
# 5020  I was riding with a friend in the summer of 19...
#
#                                        location_details  \
# 0                                                   NaN
# 1                     East side of Prince William Sound
# 2                Great swamp area, Narragansett Indians
# 3     I would rather not have exact location (listin...
# ...

# %%
# List all the columns in the table
bigfoot_file_df.columns
# Out:
# Index(['observed', 'location_details', 'county', 'state', 'season', 'title',
#        'latitude', 'longitude', 'date', 'number', 'classification', 'geohash',
#        'temperature_high', 'temperature_mid', 'temperature_low', 'dew_point',
#        'humidity', 'cloud_cover', 'moon_phase', 'precip_intensity',
#        'precip_probability', 'precip_type', 'pressure', 'summary', 'uv_index',
#        'visibility', 'wind_bearing', 'wind_speed'],
#       dtype='object')

# %%
# Create a new table that takes clean data
df2=bigfoot_file_df.dropna(subset=['number','county','state','latitude','longitude','date','season','classification',\
    'temperature_mid','humidity','cloud_cover','precip_intensity','visibility','pressure','wind_speed','observed'])
clean_bigfoot_df=df2.dropna().reset_index(drop=True)
clean_bigfoot_df
# Out:
#                                               observed  \
# 0    I was on my way to Claremont from Lebanon on R...
# 1    It was August of 1977 and I had missed my ride...
# 2    After getting online to your site we decided t...
# 3    I've told very few people this story for fear ...
# 4    I used to own a horse boarding facility which ...
# ..                                                 ...
# 716  I saw something along Interstate 75 South in K...
# 717  This was about 1980-1983, I lived in Carter Co...
# 718  My sister and I, while traveling home through ...
# 719  well it was really dark outside and i could no...
# 720  OK, let me start by saying I have always been ...
#
#                                       location_details             county  \
# 0    Close to Claremont down 120 not far from Kings...    Sullivan County
# 1    Waterloo Road, near the Sussex - Warren County...      Warren County
# 2                               Wayne National Forrest  Washington County
# ...

# %%
# Columns we're interested in:
final_df = clean_bigfoot_df[['number','county','state','latitude','longitude','classification','date','season',\
    'temperature_mid','humidity','cloud_cover','precip_intensity','visibility','pressure','wind_speed','observed']]
final_df.head()
# Out:
#     number             county          state  latitude  longitude  \
# 0  55269.0    Sullivan County  New Hampshire  43.41549  -72.33093
# 1  49883.0      Warren County     New Jersey  40.89452  -74.79077
# 2  26830.0  Washington County           Ohio  39.42635  -81.37085
# 3   6643.0  Washington County   Rhode Island  41.43200  -71.65183
# 4  50297.0    Gallatin County        Montana  45.79220 -111.36370
#
#   classification        date  season  temperature_mid  humidity  cloud_cover  \
# 0        Class A  2016-06-07  Summer           64.245      0.79         0.61
# 1        Class B  2015-10-02  Summer           46.650      0.87         0.93
# 2        Class B  2009-10-31    Fall           51.715      0.77         0.81
# 3        Class A  1978-07-15  Summer           65.805      0.88         0.80
# 4        Class B  2015-11-26  Summer           12.920      0.65         0.08
#
#    precip_intensity  visibility  pressure  wind_speed  \
# ...

# %%
final_df.dtypes
# Out:
# number              float64
# county               object
# state                object
# latitude            float64
# longitude           float64
# classification       object
# date                 object
# season               object
# temperature_mid     float64
# humidity            float64
# cloud_cover         float64
# precip_intensity    float64
# visibility          float64
# pressure            float64
# wind_speed          float64
# observed             object
# dtype: object

# %%
final_df.count()
# Out:
# number              721
# county              721
# state               721
# latitude            721
# longitude           721
# classification      721
# date                721
# season              721
# temperature_mid     721
# humidity            721
# cloud_cover         721
# precip_intensity    721
# visibility          721
# pressure            721
# wind_speed          721
# observed            721
# dtype: int64

# %%
final_df = final_df.rename(
    columns={'number':'Number','county':'County','state':'State','latitude':'Latitude',\
        'longitude':'Longitude','classification':'Classification','date':'Date','season':'Season',\
        'temperature_mid':'Temperature','humidity':'Humidity','cloud_cover':'Cloud_cover','precip_intensity':\
            'Precip_intensity','visibility':'Visibility','pressure':'Pressure','wind_speed':'Wind_speed','observed':'Observed'})
final_df.head()
# Out:
#     Number             County          State  Latitude  Longitude  \
# 0  55269.0    Sullivan County  New Hampshire  43.41549  -72.33093
# 1  49883.0      Warren County     New Jersey  40.89452  -74.79077
# 2  26830.0  Washington County           Ohio  39.42635  -81.37085
# 3   6643.0  Washington County   Rhode Island  41.43200  -71.65183
# 4  50297.0    Gallatin County        Montana  45.79220 -111.36370
#
#   Classification        Date  Season  Temperature  Humidity  Cloud_cover  \
# 0        Class A  2016-06-07  Summer       64.245      0.79         0.61
# 1        Class B  2015-10-02  Summer       46.650      0.87         0.93
# 2        Class B  2009-10-31    Fall       51.715      0.77         0.81
# 3        Class A  1978-07-15  Summer       65.805      0.88         0.80
# 4        Class B  2015-11-26  Summer       12.920      0.65         0.08
#
#    Precip_intensity  Visibility  Pressure  Wind_speed  \
# 0            0.0010        9.70    998.87        0.49
# ...

# %%
# Change number & temperature_mid to int
final_df['Number'] = final_df['Number'].astype('int64')
final_df["Temperature"] = final_df['Temperature'].astype('int64')
final_df['County'] = final_df['County'].astype('string')
final_df['State'] = final_df['State'].astype('string')
final_df['Classification'] = final_df['Classification'].astype('string')
final_df['Date'] = final_df['Date'].astype('string')
final_df['Season'] = final_df['Season'].astype('string')
final_df['Observed'] = final_df['Observed'].astype('string')

final_df.head()
# Out:
#    Number             County          State  Latitude  Longitude  \
# 0   55269    Sullivan County  New Hampshire  43.41549  -72.33093
# 1   49883      Warren County     New Jersey  40.89452  -74.79077
# 2   26830  Washington County           Ohio  39.42635  -81.37085
# 3    6643  Washington County   Rhode Island  41.43200  -71.65183
# 4   50297    Gallatin County        Montana  45.79220 -111.36370
#
#   Classification        Date  Season  Temperature  Humidity  Cloud_cover  \
# 0        Class A  2016-06-07  Summer           64      0.79         0.61
# 1        Class B  2015-10-02  Summer           46      0.87         0.93
# 2        Class B  2009-10-31    Fall           51      0.77         0.81
# 3        Class A  1978-07-15  Summer           65      0.88         0.80
# 4        Class B  2015-11-26  Summer           12      0.65         0.08
#
#    Precip_intensity  Visibility  Pressure  Wind_speed  \
# 0            0.0010        9.70    998.87        0.49
# ...

# %%
final_df.dtypes
# Out:
# Number                int64
# County               string
# State                string
# Latitude            float64
# Longitude           float64
# Classification       string
# Date                 string
# Season               string
# Temperature           int64
# Humidity            float64
# Cloud_cover         float64
# Precip_intensity    float64
# Visibility          float64
# Pressure            float64
# Wind_speed          float64
# Observed             string
# dtype: object

# %%
# Export Pandas DataFrame to CSV
final_df.to_csv('bigfoot_clean_file.csv', encoding='utf-8')
